# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Bank.csv')
df.describe()

# %%
from sklearn.preprocessing import StandardScaler
#取出age、balance、duration、campaign、previous
newdf = df[['age','balance','duration','campaign','previous']]
#標準化
scaler = StandardScaler().fit(newdf)
df_std = scaler.transform(newdf)
#建立新的tab
df2 = pd.DataFrame(df_std, columns = ['age','balance','duration','campaign','previous'])
df2.describe()

df3 = df2[["age","balance"]]

# %% [markdown]
# # kmeans

# %%
km = KMeans(n_clusters=3, init='random')
y_pred = km.fit_predict(df3)

# %%
lst_dst = []

# 嘗試 10 個 k 值並記錄分群結果的 SSE
for i in range(1, 11):
    km = KMeans(n_clusters=i)
    km.fit(df3)
    lst_dst.append(km.inertia_)

plt.plot(range(1, 11), lst_dst, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion');

# %%
plt.title('KMeans=3 groups')
plt.scatter(df3["age"], df3["balance"], c=y_pred, cmap=plt.cm.Set1)
plt.tight_layout()
plt.show()

# %%
for i in range(1,11):
    km = KMeans(n_clusters=i, init='random')
    y_pred = km.fit_predict(df3)
    plt.title('KMeans=%s groups'%(i))
    plt.scatter(df3["age"], df3["balance"], c=y_pred, cmap=plt.cm.Set1)
    plt.tight_layout()
    plt.show()

# %%
from matplotlib import cm
from sklearn.metrics import silhouette_samples, silhouette_score

for n_clusters in range(2,7):
    fig, ax = plt.subplots(1, 1, dpi=100)
    # 雖然輪廓係數範圍是[-1, 1]，但這裡只顯示[-0.2, 0.8]之間
    ax.set_xlim([-.2, .8])
    ax.set_ylim([0, len(df3)+(n_clusters+1)*10])
    # 建立 k-means 模型並擬合數據
    km = KMeans(n_clusters=n_clusters, random_state=0)
    y_pred = km.fit_predict(df3)
    # 取出分群結果的標籤
    labels = np.unique(y_pred)
    # 計算所有樣本的輪廓係數平均值
    silhouette_avg = silhouette_score(df3, y_pred)
    print("n_clusters =", n_clusters,
          "，所有樣本的輪廓係數平均 =", silhouette_avg)
    # 計算每個樣本的輪廓係數
    silhouette = silhouette_samples(df3, y_pred, 
                                    metric='euclidean')
    y_lower = 10
    for i, c in enumerate(labels):
        c_silhouette = silhouette[y_pred == c]
        c_silhouette.sort()
        size_cluster_i = c_silhouette.shape[0]
        y_upper = y_lower + size_cluster_i
        # 產生顏色編號，並填入區間內
        color = cm.nipy_spectral(float(i)/n_clusters)
        ax.fill_betweenx(np.arange(y_lower, y_upper), 0, 
                         c_silhouette, facecolor=color, 
                         edgecolor=color, alpha=0.7)
        # 標示集群標籤
        ax.text(-0.05, y_lower+0.5*size_cluster_i, str(i))
        y_lower = y_upper + 10
        
    ax.set_xlabel("The silhouette coefficient values")
    ax.set_ylabel("Cluster label")
    
    ax.axvline(x=silhouette_avg, color="red", linestyle="--")
    ax.set_yticks([])
    ax.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8])
# Out:
# n_clusters = 2 ，所有樣本的輪廓係數平均 = 0.47981603947164414
# n_clusters = 3 ，所有樣本的輪廓係數平均 = 0.5095997936303313
# n_clusters = 4 ，所有樣本的輪廓係數平均 = 0.5224483284538749
# n_clusters = 5 ，所有樣本的輪廓係數平均 = 0.4299344782224492
# n_clusters = 6 ，所有樣本的輪廓係數平均 = 0.4372033478490362

# %%
from sklearn.metrics import silhouette_score

for n_clusters in range(2,7):
    fig, ax = plt.subplots(1, 1, dpi=100)
    # 雖然輪廓係數範圍是[-1, 1]，但這裡只顯示[-0.2, 0.8]之間
    ax.set_xlim([-.2, .8])
    ax.set_ylim([0, len(df3)+(n_clusters+1)*10])
    # 建立 k-means 模型並擬合數據
    km = KMeans(n_clusters=n_clusters, random_state=0)
    y_pred = km.fit_predict(df3)
    # 取出分群結果的標籤
    labels = np.unique(y_pred)
    # 計算所有樣本的輪廓係數平均值
    silhouette_avg = silhouette_score(df3, y_pred)
    print("n_clusters =", n_clusters,
          "，所有樣本的輪廓係數平均 =", silhouette_avg)
# Out:
# n_clusters = 2 ，所有樣本的輪廓係數平均 = 0.47981603947164414
# n_clusters = 3 ，所有樣本的輪廓係數平均 = 0.5095997936303313
# n_clusters = 4 ，所有樣本的輪廓係數平均 = 0.5224483284538749
# n_clusters = 5 ，所有樣本的輪廓係數平均 = 0.4299344782224492
# n_clusters = 6 ，所有樣本的輪廓係數平均 = 0.4372033478490362
